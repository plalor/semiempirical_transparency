# %%
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
from utils import *

path = "/Users/peter/Work/radiography/data/"
path_sim = "/Users/peter/Work/semiempirical_transparency/out/"
outfile = "/Users/peter/Work/semiempirical_transparency/paper/figs/"

H = "10"
L = "6"
H_twiddle = "9.7"
L_twiddle = "6.3"
thetaMax = np.arcsin(400 / 700)

# %% [markdown]
# ### Loading simulated parameters

# %%
b_10 = np.load(path + "b10MeV_10.npy")
b_6 = np.load(path + "b6MeV_10.npy")
b_4 = np.load(path + "b4MeV_10.npy")
 
R = np.load(path + "R_10.npy")
E_g = np.load(path + "E_g_10.npy")
E_dep = np.load(path + "E_dep_10.npy")

lmbdaRange = np.linspace(0, 500, 101)
zRange = np.arange(1, 101)
attenMat = calcAttenMat_tot(E_g, zRange)
attenMat_PE = calcAttenMat_PE(E_g, zRange)
attenMat_CS = calcAttenMat_CS(E_g, zRange)
attenMat_PP = calcAttenMat_PP(E_g, zRange)
  
if (H, L) == ("6", "4"):
    b_H = b_6
    b_L = b_4
    yrange = [-2, 0]
elif (H, L) == ("10", "6"):
    b_H = b_10
    b_L = b_6
    yrange = [-2, 0]
elif (H, L) == ("10", "4"):
    b_H = b_10
    b_L = b_4
    yrange = [-4, 0]
else:
    raise ValueError("'H' or 'L' not understood, must be '10', '6', or '4'")
    
norm = mpl.colors.Normalize(vmin=zRange[0], vmax=zRange[-1])
colormap = mpl.colormaps["viridis"]
cmap = mpl.cm.ScalarMappable(norm=norm, cmap=colormap)
color = lambda Z: cmap.to_rgba(Z)
n = len(lmbdaRange)
xrange = [0, 10]
xticks = np.arange(11)
yticks = np.linspace(np.ceil(2*yrange[0])/2, np.floor(2*yrange[1])/2, int(2*(yrange[1] - yrange[0]) + 1))

# %% [markdown]
# ### Adding Compound Materials

# %%
compound_material = {}
compound_Z = {}
compound_f = {}
compound_c = {}

compound_material[101] = "Polyethylene (CH2)"
compound_Z[101] = np.array([1, 6])
compound_f[101] = np.array([0.143711, 0.856289])
compound_c[101] = color(6)

compound_material[102] = "Silver Chloride (AgCl)"
compound_Z[102] = np.array([17, 47])
compound_f[102] = np.array([0.247368, 0.752632])
compound_c[102] = color(47)

compound_material[103] = "Uranium Oxide (UO2)"
compound_Z[103] = np.array([8, 92])
compound_f[103] = np.array([0.118502, 0.881498])
compound_c[103] = color(92)

# %% [markdown]
# ### Loading simulated data

# %%
energies = np.array(["10", "6", "4", "9.7", "6.3", "5.7"])

### Calibration data
# lookup_alpha_calib = calcLookupTables("lookup_alpha_calib.npy", path_sim + "calib/", energies, thetaMax, R, E_dep, attenMat, zRange)
lookup_alpha_calib = calcLookupTables("lookup_alpha_calib.npy")
Z_arr_calib, Z_vals_calib, Z_compound_calib, alpha_H_calib, alpha_L_calib, sigma_H_calib, sigma_L_calib, lmbda_H_calib, lmbda_L_calib = extractFromTables(lookup_alpha_calib, H, L)
Z_arr_calib_twiddle, Z_vals_calib_twiddle, Z_compound_calib_twiddle, alpha_H_calib_twiddle, alpha_L_calib_twiddle, sigma_H_calib_twiddle, sigma_L_calib_twiddle, lmbda_H_calib_twiddle, lmbda_L_calib_twiddle = extractFromTables(lookup_alpha_calib, H_twiddle, L_twiddle)

### Test data
# lookup_alpha = calcLookupTables("lookup_alpha.npy", path_sim, energies, thetaMax, R, E_dep, attenMat, zRange, compound_Z, compound_f)
lookup_alpha = calcLookupTables("lookup_alpha.npy")
Z_arr, Z_vals, Z_compound, alpha_H_arr, alpha_L_arr, sigma_H_arr, sigma_L_arr, lmbda_H_arr, lmbda_L_arr = extractFromTables(lookup_alpha, H, L)
Z_arr_twiddle, Z_vals_twiddle, Z_compound_twiddle, alpha_H_arr_twiddle, alpha_L_arr_twiddle, sigma_H_arr_twiddle, sigma_L_arr_twiddle, lmbda_H_arr_twiddle, lmbda_L_arr_twiddle = extractFromTables(lookup_alpha, H_twiddle, L_twiddle)

# %% [markdown]
# ### Alpha-curve for free streaming model data

# %%
fig, ax1 = plt.subplots(1, figsize = [8, 8])

for Z in zRange:
    alpha_H0 = calcAlpha(lmbdaRange, [Z], b_H, R, E_dep, attenMat, zRange)
    alpha_L0 = calcAlpha(lmbdaRange, [Z], b_L, R, E_dep, attenMat, zRange)        
    ax1.plot(alpha_H0, alpha_H0 - alpha_L0, linewidth = 1, c=color(Z))

ax1.set_xlim(xrange)
ax1.set_ylim(yrange)
ax1.set_xticks(xticks)
ax1.set_yticks(yticks)
ax1.tick_params(labelsize=16)
ax1.grid()
ax1.set_xlabel(r"$\alpha_H(\lambda, Z)$", fontsize=19)
ax1.set_ylabel(r"$\alpha_H(\lambda, Z) - \alpha_L(\lambda, Z)$", fontsize=19)
ax1.text(0.1, 0.97*yrange[0], "{%s, %s} MeV" % (H, L), fontsize = 19)
fig.subplots_adjust(right=0.85)
cbar_ax = fig.add_axes([0.86, 0.125, 0.04, 0.755])
fig.colorbar(cmap, cax=cbar_ax)
cbar_ax.set_ylabel("Atomic Number (Z)", fontsize=19)
cbar_ax.tick_params(labelsize=16)

plt.savefig(outfile + "alpha_curve_%s%s.png" % (H, L), bbox_inches = "tight")

# %% [markdown]
# ### Plotting simulated data against the free streaming model

# %%
fig, ax1 = plt.subplots(1, figsize = [8, 8])

for Z in Z_vals:
    ### lookup simulated values
    lmbda_H, alpha_H, sigma_H = lookup_alpha[H][Z]
    lmbda_L, alpha_L, sigma_L = lookup_alpha[L][Z]
    ax1.errorbar(alpha_H, alpha_H - alpha_L, xerr = sigma_H, 
                 yerr = np.sqrt(sigma_H**2 + sigma_L**2), 
                 elinewidth=2, capsize=2, ecolor = color(Z), ls='none')
        
    ### plot against theory
    alpha_H0 = calcAlpha(lmbdaRange, [Z], b_H, R, E_dep, attenMat, zRange)
    alpha_L0 = calcAlpha(lmbdaRange, [Z], b_L, R, E_dep, attenMat, zRange)        
    ax1.plot(alpha_H0, alpha_H0 - alpha_L0, linewidth = 1, linestyle = 'dashed', c=color(Z))

bias_H = calcBias(alpha_H_arr, sigma_H_arr, lmbda_H_arr, Z_arr, b_H, R, E_dep, attenMat, zRange)
bias_L = calcBias(alpha_L_arr, sigma_L_arr, lmbda_L_arr, Z_arr, b_L, R, E_dep, attenMat, zRange)
print("Bias_H = %.3g" % bias_H)
print("Bias_L = %.3g" % bias_L)

ax1.set_xlim(xrange)
ax1.set_ylim(yrange)
ax1.set_xticks(xticks)
ax1.set_yticks(yticks)
ax1.tick_params(labelsize=16)
ax1.grid()
ax1.set_xlabel(r"$\alpha_H(\lambda, Z)$", fontsize=19)
ax1.set_ylabel(r"$\alpha_H(\lambda, Z) - \alpha_L(\lambda, Z)$", fontsize=19)
ax1.text(0.1, 0.97*yrange[0], "{%s, %s} MeV" % (H, L), fontsize = 19)
fig.subplots_adjust(right=0.85)
cbar_ax = fig.add_axes([0.86, 0.125, 0.04, 0.755])
fig.colorbar(cmap, cax=cbar_ax)
cbar_ax.set_ylabel("Atomic Number (Z)", fontsize=19)
cbar_ax.tick_params(labelsize=16)

plt.savefig(outfile + "alpha_curve_%s%s_errorbar.png" % (H, L), bbox_inches = "tight")
# Out:
# Bias_H = 0.0491
# Bias_L = 0.0269

# %%
fig, ax1 = plt.subplots(1, figsize = [8, 8])

for Z in Z_vals:
    ### lookup simulated values
    lmbda_H, alpha_H, sigma_H = lookup_alpha[H][Z]
    #ax1.errorbar(lmbda_H, alpha_H, yerr = sigma_H, 
    #             elinewidth=2, capsize=1, ecolor = color(Z), ls='none')
    ax1.scatter(lmbda_H, alpha_H, s=5, color = color(Z))
        
    ### plot against theory
    alpha_H0 = calcAlpha(lmbdaRange, [Z], b_H, R, E_dep, attenMat, zRange)
    ax1.plot(lmbdaRange, alpha_H0, linewidth = 0.5, linestyle = 'dashed', c=color(Z))

ax1.set_xlim([0, 250])
ax1.set_ylim([0, 11])
ax1.tick_params(labelsize=16)
ax1.grid()
ax1.set_xlabel(r"$\lambda$ (g/cm^2)", fontsize=19)
ax1.set_ylabel(r"$\alpha_H(\lambda, Z)$", fontsize=19)
fig.subplots_adjust(right=0.85)
cbar_ax = fig.add_axes([0.86, 0.125, 0.04, 0.755])
fig.colorbar(cmap, cax=cbar_ax)
cbar_ax.set_ylabel("Atomic Number (Z)", fontsize=19)
cbar_ax.tick_params(labelsize=16)

plt.savefig(outfile + "alpha_lambda_%s" % H, bbox_inches = "tight")

# %%
fig, ax1 = plt.subplots(1, figsize = [8, 8])

for Z in Z_vals:
    ### lookup simulated values
    lmbda_L, alpha_L, sigma_L = lookup_alpha[L][Z]
    ax1.scatter(lmbda_L, alpha_L, s=5, color = color(Z))
        
    ### plot against theory
    alpha_L0 = calcAlpha(lmbdaRange, [Z], b_L, R, E_dep, attenMat, zRange)
    ax1.plot(lmbdaRange, alpha_L0, linewidth = 0.5, linestyle = 'dashed', c=color(Z))

ax1.set_xlim([0, 250])
ax1.set_ylim([0, 11])

ax1.tick_params(labelsize=16)
ax1.grid()
ax1.set_xlabel(r"$\lambda$ (g/cm^2)", fontsize=19)
ax1.set_ylabel(r"$\alpha_L(\lambda, Z)$", fontsize=19)
fig.subplots_adjust(right=0.85)
cbar_ax = fig.add_axes([0.86, 0.125, 0.04, 0.755])
fig.colorbar(cmap, cax=cbar_ax)
cbar_ax.set_ylabel("Atomic Number (Z)", fontsize=19)
cbar_ax.tick_params(labelsize=16)

plt.savefig(outfile + "alpha_lambda_%s" % L, bbox_inches = "tight")

# %% [markdown]
# ### Z of best fit

# %%
fig, ax1 = plt.subplots(1, figsize = [8, 8])

for Z in Z_vals:
    ### lookup simulated values
    lmbda_H, alpha_H, sigma_H = lookup_alpha[H][Z]
    lmbda_L, alpha_L, sigma_L = lookup_alpha[L][Z]
    ax1.errorbar(alpha_H, alpha_H - alpha_L, xerr = sigma_H, 
                 yerr = np.sqrt(sigma_H**2 + sigma_L**2), 
                 elinewidth=2, capsize=2, ecolor = color(Z), ls='none')
        
    Z_fit, loss_fit = fitToTheory(alpha_H, alpha_L, b_H, b_L, R, E_dep, attenMat, attenMat, zRange)
    print("True Z: %d; Fit Z: %s; Loss: %s" % (Z, Z_fit, loss_fit))
    
    ### plot against theory
    alpha_H0 = calcAlpha(lmbdaRange, [Z_fit[0]], b_H, R, E_dep, attenMat, zRange)
    alpha_L0 = calcAlpha(lmbdaRange, [Z_fit[0]], b_L, R, E_dep, attenMat, zRange)        
    ax1.plot(alpha_H0, alpha_H0 - alpha_L0, linewidth = 1, linestyle = 'dashed', c=color(Z))

ax1.set_xlim(xrange)
ax1.set_ylim(yrange)
ax1.set_xticks(xticks)
ax1.set_yticks(yticks)
ax1.tick_params(labelsize=16)
ax1.grid()
ax1.set_xlabel(r"$\alpha_H(\lambda, Z)$", fontsize=19)
ax1.set_ylabel(r"$\alpha_H(\lambda, Z) - \alpha_L(\lambda, Z)$", fontsize=19)
ax1.text(0.1, 0.97*yrange[0], "{%s, %s} MeV" % (H, L), fontsize = 19)
fig.subplots_adjust(right=0.85)
cbar_ax = fig.add_axes([0.86, 0.125, 0.04, 0.755])
fig.colorbar(cmap, cax=cbar_ax)
cbar_ax.set_ylabel("Atomic Number (Z)", fontsize=19)
cbar_ax.tick_params(labelsize=16)

plt.savefig(outfile + "alpha_curve_%s%s_fit.png" % (H, L), bbox_inches = "tight")
# Out:
# True Z: 1; Fit Z: [1]; Loss: [0.00196506]
# True Z: 6; Fit Z: [5]; Loss: [0.00013279]
# True Z: 13; Fit Z: [12]; Loss: [0.00020412]
# True Z: 20; Fit Z: [18]; Loss: [0.00011842]
# True Z: 26; Fit Z: [24]; Loss: [0.00010939]
# True Z: 32; Fit Z: [29]; Loss: [0.00010079]
# True Z: 40; Fit Z: [37]; Loss: [0.00012203]
# True Z: 47; Fit Z: [43]; Loss: [9.11567698e-05]
# True Z: 55; Fit Z: [51]; Loss: [7.27924432e-05]
# True Z: 64; Fit Z: [ 59 100]; Loss: [8.56474286e-05 1.44495845e-04]
# True Z: 74; Fit Z: [70 92]; Loss: [0.00018687 0.0001218 ]
# True Z: 82; Fit Z: [89]; Loss: [0.00010662]
# True Z: 92; Fit Z: [85]; Loss: [9.47802626e-05]

# %% [markdown]
# ### Semiempirical mass attenuation coefficient

# %%
a0_H, b0_H, c0_H = fitSemiempirical(alpha_H_arr, lmbda_H_arr, Z_arr, b_H, R, E_dep, attenMat, attenMat_PE, attenMat_CS, attenMat_PP, zRange)
a0_L, b0_L, c0_L = fitSemiempirical(alpha_L_arr, lmbda_L_arr, Z_arr, b_L, R, E_dep, attenMat, attenMat_PE, attenMat_CS, attenMat_PP, zRange)
attenMat_H = attenMat + (a0_H-1)*attenMat_PE + (b0_H-1)*attenMat_CS + (c0_H-1)*attenMat_PP
attenMat_L = attenMat + (a0_L-1)*attenMat_PE + (b0_L-1)*attenMat_CS + (c0_L-1)*attenMat_PP

fig, ax1 = plt.subplots(1, figsize = [8, 8])

for Z in Z_vals:
    ### lookup simulated values
    lmbda_H, alpha_H, sigma_H = lookup_alpha[H][Z]
    lmbda_L, alpha_L, sigma_L = lookup_alpha[L][Z]
    ax1.errorbar(alpha_H, alpha_H - alpha_L, xerr = sigma_H, 
                 yerr = np.sqrt(sigma_H**2 + sigma_L**2), 
                 elinewidth=2, capsize=2, ecolor = color(Z), ls='none')
        
    ### plot against theory
    alpha_H0 = calcAlpha(lmbdaRange, [Z], b_H, R, E_dep, attenMat_H, zRange)
    alpha_L0 = calcAlpha(lmbdaRange, [Z], b_L, R, E_dep, attenMat_L, zRange)        
    ax1.plot(alpha_H0, alpha_H0 - alpha_L0, linewidth = 1, linestyle = 'dashed', c=color(Z))

bias_H = calcBias(alpha_H_arr, sigma_H_arr, lmbda_H_arr, Z_arr, b_H, R, E_dep, attenMat_H, zRange)
bias_L = calcBias(alpha_L_arr, sigma_L_arr, lmbda_L_arr, Z_arr, b_L, R, E_dep, attenMat_L, zRange)
print("Bias_H = %.3g" % bias_H)
print("Bias_L = %.3g" % bias_L)

ax1.set_xlim(xrange)
ax1.set_ylim(yrange)
ax1.set_xticks(xticks)
ax1.set_yticks(yticks)
ax1.tick_params(labelsize=16)
ax1.grid()
ax1.set_xlabel(r"$\alpha_H(\lambda, Z)$", fontsize=19)
ax1.set_ylabel(r"$\alpha_H(\lambda, Z) - \alpha_L(\lambda, Z)$", fontsize=19)
# ax1.set_xlabel(r"$-\log T_H(\lambda, Z)$", fontsize=19)
# ax1.set_ylabel(r"$\log T_L(\lambda, Z) - \log T_H(\lambda, Z)$", fontsize=19)
ax1.text(0.1, 0.97*yrange[0], "{%s, %s} MeV" % (H, L), fontsize = 19)
fig.subplots_adjust(right=0.85)
cbar_ax = fig.add_axes([0.86, 0.125, 0.04, 0.755])
fig.colorbar(cmap, cax=cbar_ax)
cbar_ax.set_ylabel("Atomic Number (Z)", fontsize=19)
cbar_ax.tick_params(labelsize=16)

plt.savefig(outfile + "alpha_curve_%s%s_semiempirical.png" % (H, L), bbox_inches = "tight")
# Out:
# Minimum found at a = 1.1658, b=0.9861, c=0.9920 with a loss of 2.502e-04
# Minimum found at a = 1.1045, b=1.0054, c=0.9612 with a loss of 4.931e-04
# Bias_H = 0.0145
# Bias_L = 0.0212

# %% [markdown]
# ### Z of best fit using semiempirical parameters

# %%
fig, ax1 = plt.subplots(1, figsize = [8, 8])

for Z in Z_vals:
    ### lookup simulated values
    lmbda_H, alpha_H, sigma_H = lookup_alpha[H][Z]
    lmbda_L, alpha_L, sigma_L = lookup_alpha[L][Z]
    ax1.errorbar(alpha_H, alpha_H - alpha_L, xerr = sigma_H, 
                 yerr = np.sqrt(sigma_H**2 + sigma_L**2), 
                 elinewidth=2, capsize=2, ecolor = color(Z), ls='none')
        
    Z_fit, loss_fit = fitToTheory(alpha_H, alpha_L, b_H, b_L, R, E_dep, attenMat_H, attenMat_L, zRange)
    print("True Z: %d; Fit Z: %s; Loss: %s" % (Z, Z_fit, loss_fit))
    
    ### plot against theory
    alpha_H0 = calcAlpha(lmbdaRange, [Z_fit[0]], b_H, R, E_dep, attenMat_H, zRange)
    alpha_L0 = calcAlpha(lmbdaRange, [Z_fit[0]], b_L, R, E_dep, attenMat_L, zRange)        
    ax1.plot(alpha_H0, alpha_H0 - alpha_L0, linewidth = 1, linestyle = 'dashed', c=color(Z))

    ax1.set_xlim(xrange)
ax1.set_ylim(yrange)
ax1.set_xticks(xticks)
ax1.set_yticks(yticks)
ax1.tick_params(labelsize=16)
ax1.grid()
ax1.set_xlabel(r"$\alpha_H(\lambda, Z)$", fontsize=19)
ax1.set_ylabel(r"$\alpha_H(\lambda, Z) - \alpha_L(\lambda, Z)$", fontsize=19)
ax1.text(0.1, 0.97*yrange[0], "{%s, %s} MeV" % (H, L), fontsize = 19)
fig.subplots_adjust(right=0.85)
cbar_ax = fig.add_axes([0.86, 0.125, 0.04, 0.755])
fig.colorbar(cmap, cax=cbar_ax)
cbar_ax.set_ylabel("Atomic Number (Z)", fontsize=19)
cbar_ax.tick_params(labelsize=16)

plt.savefig(outfile + "alpha_curve_%s%s_semiempirical_fit.png" % (H, L), bbox_inches = "tight")
# Out:
# True Z: 1; Fit Z: [1]; Loss: [0.00011198]
# True Z: 6; Fit Z: [6]; Loss: [0.00016611]
# True Z: 13; Fit Z: [13]; Loss: [0.00014563]
# True Z: 20; Fit Z: [20]; Loss: [7.9309756e-05]
# True Z: 26; Fit Z: [26]; Loss: [4.93941385e-05]
# True Z: 32; Fit Z: [32]; Loss: [6.26510765e-05]
# True Z: 40; Fit Z: [40]; Loss: [8.4129002e-05]
# True Z: 47; Fit Z: [47]; Loss: [5.82514879e-05]
# True Z: 55; Fit Z: [55]; Loss: [4.4968111e-05]
# True Z: 64; Fit Z: [63]; Loss: [5.94193724e-05]
# True Z: 74; Fit Z: [75 96]; Loss: [0.00013248 0.0001003 ]
# True Z: 82; Fit Z: [92]; Loss: [6.69212234e-05]
# True Z: 92; Fit Z: [88]; Loss: [4.55691835e-05]

# %% [markdown]
# ### Calibrate using Z=6, Z=26, and Z=82

# %%
fig, ax1 = plt.subplots(1, figsize = [8, 8])

lmbda_calib = 150
cut = np.abs(lmbda_H_calib - 1.068*lmbda_calib) < 10
a0_H, b0_H, c0_H = fitSemiempirical(alpha_H_calib[cut], lmbda_H_calib[cut], Z_arr_calib[cut], b_H, R, E_dep, attenMat, attenMat_PE, attenMat_CS, attenMat_PP, zRange)
a0_L, b0_L, c0_L = fitSemiempirical(alpha_L_calib[cut], lmbda_L_calib[cut], Z_arr_calib[cut], b_L, R, E_dep, attenMat, attenMat_PE, attenMat_CS, attenMat_PP, zRange)

# a0_H, b0_H, c0_H = fitSemiempirical(alpha_H_calib, lmbda_H_calib, Z_arr_calib, b_H, R, E_dep, attenMat, attenMat_PE, attenMat_CS, attenMat_PP, zRange)
# a0_L, b0_L, c0_L = fitSemiempirical(alpha_L_calib, lmbda_L_calib, Z_arr_calib, b_L, R, E_dep, attenMat, attenMat_PE, attenMat_CS, attenMat_PP, zRange)
attenMat_H = attenMat + (a0_H-1)*attenMat_PE + (b0_H-1)*attenMat_CS + (c0_H-1)*attenMat_PP
attenMat_L = attenMat + (a0_L-1)*attenMat_PE + (b0_L-1)*attenMat_CS + (c0_L-1)*attenMat_PP

for Z in Z_vals:
    ### lookup simulated values
    lmbda_H, alpha_H, sigma_H = lookup_alpha[H][Z]
    lmbda_L, alpha_L, sigma_L = lookup_alpha[L][Z]
    ax1.errorbar(alpha_H, alpha_H - alpha_L, xerr = sigma_H, 
                 yerr = np.sqrt(sigma_H**2 + sigma_L**2), 
                 elinewidth=2, capsize=2, ecolor = color(Z), ls='none')
        
    ### plot against theory
    alpha_H0 = calcAlpha(lmbdaRange, [Z], b_H, R, E_dep, attenMat_H, zRange)
    alpha_L0 = calcAlpha(lmbdaRange, [Z], b_L, R, E_dep, attenMat_L, zRange)        
    ax1.plot(alpha_H0, alpha_H0 - alpha_L0, linewidth = 1, linestyle = 'dashed', c=color(Z))

bias_H = calcBias(alpha_H_arr, sigma_H_arr, lmbda_H_arr, Z_arr, b_H, R, E_dep, attenMat_H, zRange)
bias_L = calcBias(alpha_L_arr, sigma_L_arr, lmbda_L_arr, Z_arr, b_L, R, E_dep, attenMat_L, zRange)
print("Bias_H = %.3g" % bias_H)
print("Bias_L = %.3g" % bias_L)

ax1.set_xlim(xrange)
ax1.set_ylim(yrange)
ax1.set_xticks(xticks)
ax1.set_yticks(yticks)
ax1.tick_params(labelsize=16)
ax1.grid()
ax1.set_xlabel(r"$\alpha_H(\lambda, Z)$", fontsize=19)
ax1.set_ylabel(r"$\alpha_H(\lambda, Z) - \alpha_L(\lambda, Z)$", fontsize=19)
ax1.text(0.1, 0.97*yrange[0], "{%s, %s} MeV" % (H, L), fontsize = 19)
fig.subplots_adjust(right=0.85)
cbar_ax = fig.add_axes([0.86, 0.125, 0.04, 0.755])
fig.colorbar(cmap, cax=cbar_ax)
cbar_ax.set_ylabel("Atomic Number (Z)", fontsize=19)
cbar_ax.tick_params(labelsize=16)

plt.savefig(outfile + "alpha_curve_%s%s_calibrated.png" % (H, L), bbox_inches = "tight")
# Out:
# Minimum found at a = 1.1124, b=0.9856, c=0.9943 with a loss of 2.788e-13
# Minimum found at a = 0.9803, b=1.0025, c=0.9842 with a loss of 4.618e-12
# Bias_H = 0.0153
# Bias_L = 0.0239

# %%
fig, ax1 = plt.subplots(1, figsize = [8, 8])

for Z in Z_vals:
    ### lookup simulated values
    lmbda_H, alpha_H, sigma_H = lookup_alpha[H][Z]
    lmbda_L, alpha_L, sigma_L = lookup_alpha[L][Z]
    ax1.errorbar(alpha_H, alpha_H - alpha_L, xerr = sigma_H, 
                 yerr = np.sqrt(sigma_H**2 + sigma_L**2), 
                 elinewidth=2, capsize=2, ecolor = color(Z), ls='none')
        
    Z_fit, loss_fit = fitToTheory(alpha_H, alpha_L, b_H, b_L, R, E_dep, attenMat_H, attenMat_L, zRange)
    print("True Z: %d; Fit Z: %s; Loss: %s" % (Z, Z_fit, loss_fit))
    
    ### plot against theory
    alpha_H0 = calcAlpha(lmbdaRange, [Z_fit[0]], b_H, R, E_dep, attenMat_H, zRange)
    alpha_L0 = calcAlpha(lmbdaRange, [Z_fit[0]], b_L, R, E_dep, attenMat_L, zRange)        
    ax1.plot(alpha_H0, alpha_H0 - alpha_L0, linewidth = 1, linestyle = 'dashed', c=color(Z))

ax1.set_xlim(xrange)
ax1.set_ylim(yrange)
ax1.set_xticks(xticks)
ax1.set_yticks(yticks)
ax1.tick_params(labelsize=16)
ax1.grid()
ax1.set_xlabel(r"$\alpha_H(\lambda, Z)$", fontsize=19)
ax1.set_ylabel(r"$\alpha_H(\lambda, Z) - \alpha_L(\lambda, Z)$", fontsize=19)
ax1.text(0.1, 0.97*yrange[0], "{%s, %s} MeV" % (H, L), fontsize = 19)
fig.subplots_adjust(right=0.85)
cbar_ax = fig.add_axes([0.86, 0.125, 0.04, 0.755])
fig.colorbar(cmap, cax=cbar_ax)
cbar_ax.set_ylabel("Atomic Number (Z)", fontsize=19)
cbar_ax.tick_params(labelsize=16)

plt.savefig(outfile + "alpha_curve_%s%s_calibrated_fit.png" % (H, L), bbox_inches = "tight")
# Out:
# True Z: 1; Fit Z: [1]; Loss: [0.00011401]
# True Z: 6; Fit Z: [6]; Loss: [0.00010707]
# True Z: 13; Fit Z: [13]; Loss: [0.00014571]
# True Z: 20; Fit Z: [20]; Loss: [0.00010594]
# True Z: 26; Fit Z: [26]; Loss: [6.53715905e-05]
# True Z: 32; Fit Z: [32]; Loss: [7.41799986e-05]
# True Z: 40; Fit Z: [41]; Loss: [0.00011573]
# True Z: 47; Fit Z: [48]; Loss: [8.16731928e-05]
# True Z: 55; Fit Z: [56]; Loss: [7.27087969e-05]
# True Z: 64; Fit Z: [64]; Loss: [9.24371334e-05]
# True Z: 74; Fit Z: [ 75 100]; Loss: [0.0001902  0.00010745]
# True Z: 82; Fit Z: [80 97]; Loss: [1.54917945e-04 8.34757927e-05]
# True Z: 92; Fit Z: [95]; Loss: [6.12447035e-05]

# %% [markdown]
# ### Source Energy Fluctuations

# %%
fig, ax1 = plt.subplots(1, figsize = [8, 8])

lmbda_calib = 150
cut = np.abs(lmbda_H_calib_twiddle - 1.068*lmbda_calib) < 10
a0_H, b0_H, c0_H = fitSemiempirical(alpha_H_calib_twiddle[cut], lmbda_H_calib_twiddle[cut], Z_arr_calib_twiddle[cut], b_H, R, E_dep, attenMat, attenMat_PE, attenMat_CS, attenMat_PP, zRange)
a0_L, b0_L, c0_L = fitSemiempirical(alpha_L_calib_twiddle[cut], lmbda_L_calib_twiddle[cut], Z_arr_calib_twiddle[cut], b_L, R, E_dep, attenMat, attenMat_PE, attenMat_CS, attenMat_PP, zRange)

attenMat_H = attenMat + (a0_H-1)*attenMat_PE + (b0_H-1)*attenMat_CS + (c0_H-1)*attenMat_PP
attenMat_L = attenMat + (a0_L-1)*attenMat_PE + (b0_L-1)*attenMat_CS + (c0_L-1)*attenMat_PP

for Z in Z_vals:
    ### lookup simulated values
    lmbda_H, alpha_H, sigma_H = lookup_alpha[H_twiddle][Z]
    lmbda_L, alpha_L, sigma_L = lookup_alpha[L_twiddle][Z]
    ax1.errorbar(alpha_H, alpha_H - alpha_L, xerr = sigma_H, 
                 yerr = np.sqrt(sigma_H**2 + sigma_L**2), 
                 elinewidth=2, capsize=2, ecolor = color(Z), ls='none')
        
    ### plot against theory
    alpha_H0 = calcAlpha(lmbdaRange, [Z], b_H, R, E_dep, attenMat_H, zRange)
    alpha_L0 = calcAlpha(lmbdaRange, [Z], b_L, R, E_dep, attenMat_L, zRange)        
    ax1.plot(alpha_H0, alpha_H0 - alpha_L0, linewidth = 1, linestyle = 'dashed', c=color(Z))

bias_H = calcBias(alpha_H_arr_twiddle, sigma_H_arr_twiddle, lmbda_H_arr_twiddle, Z_arr_twiddle, b_H, R, E_dep, attenMat_H, zRange)
bias_L = calcBias(alpha_L_arr_twiddle, sigma_L_arr_twiddle, lmbda_L_arr_twiddle, Z_arr_twiddle, b_L, R, E_dep, attenMat_L, zRange)
print("Bias_H = %.3g" % bias_H)
print("Bias_L = %.3g" % bias_L)

ax1.set_xlim(xrange)
ax1.set_ylim(yrange)
ax1.set_xticks(xticks)
ax1.set_yticks(yticks)
ax1.tick_params(labelsize=16)
ax1.grid()
ax1.set_xlabel(r"$\alpha_H(\lambda, Z)$", fontsize=19)
ax1.set_ylabel(r"$\alpha_H(\lambda, Z) - \alpha_L(\lambda, Z)$", fontsize=19)
ax1.text(0.1, 0.97*yrange[0], "{%s, %s} MeV" % (H, L), fontsize = 19)
fig.subplots_adjust(right=0.85)
cbar_ax = fig.add_axes([0.86, 0.125, 0.04, 0.755])
fig.colorbar(cmap, cax=cbar_ax)
cbar_ax.set_ylabel("Atomic Number (Z)", fontsize=19)
cbar_ax.tick_params(labelsize=16)

plt.savefig(outfile + "alpha_curve_%s%s_fluctuations.png" % (H, L), bbox_inches = "tight")
# Out:
# Minimum found at a = 1.1684, b=1.0074, c=0.9607 with a loss of 7.614e-13
# Minimum found at a = 0.8778, b=0.9692, c=1.0577 with a loss of 8.593e-12
# Bias_H = 0.014
# Bias_L = 0.0265

# %%
fig, ax1 = plt.subplots(1, figsize = [8, 8])

for Z in Z_vals:
    ### lookup simulated values
    lmbda_H, alpha_H, sigma_H = lookup_alpha[H_twiddle][Z]
    lmbda_L, alpha_L, sigma_L = lookup_alpha[L_twiddle][Z]
    ax1.errorbar(alpha_H, alpha_H - alpha_L, xerr = sigma_H, 
                 yerr = np.sqrt(sigma_H**2 + sigma_L**2), 
                 elinewidth=2, capsize=2, ecolor = color(Z), ls='none')
        
    Z_fit, loss_fit = fitToTheory(alpha_H, alpha_L, b_H, b_L, R, E_dep, attenMat_H, attenMat_L, zRange)
    print("True Z: %d; Fit Z: %s; Loss: %s" % (Z, Z_fit, loss_fit))
    
    ### plot against theory
    alpha_H0 = calcAlpha(lmbdaRange, [Z_fit[0]], b_H, R, E_dep, attenMat_H, zRange)
    alpha_L0 = calcAlpha(lmbdaRange, [Z_fit[0]], b_L, R, E_dep, attenMat_L, zRange)        
    ax1.plot(alpha_H0, alpha_H0 - alpha_L0, linewidth = 1, linestyle = 'dashed', c=color(Z))

ax1.set_xlim(xrange)
ax1.set_ylim(yrange)
ax1.set_xticks(xticks)
ax1.set_yticks(yticks)
ax1.tick_params(labelsize=16)
ax1.grid()
ax1.set_xlabel(r"$\alpha_H(\lambda, Z)$", fontsize=19)
ax1.set_ylabel(r"$\alpha_H(\lambda, Z) - \alpha_L(\lambda, Z)$", fontsize=19)
ax1.text(0.1, 0.97*yrange[0], "{%s, %s} MeV" % (H, L), fontsize = 19)
fig.subplots_adjust(right=0.85)
cbar_ax = fig.add_axes([0.86, 0.125, 0.04, 0.755])
fig.colorbar(cmap, cax=cbar_ax)
cbar_ax.set_ylabel("Atomic Number (Z)", fontsize=19)
cbar_ax.tick_params(labelsize=16)

plt.savefig(outfile + "alpha_curve_%s%s_calibrated_fit.png" % (H, L), bbox_inches = "tight")
# Out:
# True Z: 1; Fit Z: [1]; Loss: [0.00013697]
# True Z: 6; Fit Z: [6]; Loss: [0.00011686]
# True Z: 13; Fit Z: [13]; Loss: [0.00017146]
# True Z: 20; Fit Z: [20]; Loss: [9.45779248e-05]
# True Z: 26; Fit Z: [26]; Loss: [0.00018764]
# True Z: 32; Fit Z: [32]; Loss: [8.11760011e-05]
# True Z: 40; Fit Z: [41]; Loss: [0.00014369]
# True Z: 47; Fit Z: [47]; Loss: [0.00011269]
# True Z: 55; Fit Z: [55]; Loss: [0.00012028]
# True Z: 64; Fit Z: [ 63 100]; Loss: [0.00013876 0.00026404]
# True Z: 74; Fit Z: [72 96]; Loss: [0.00014349 0.00010589]
# True Z: 82; Fit Z: [90]; Loss: [0.00013549]
# True Z: 92; Fit Z: [91]; Loss: [0.00014375]

# %% [markdown]
# ### Free streaming model using mismatched spectra

# %%
fig, ax1 = plt.subplots(1, figsize = [8, 8])

for Z in Z_vals:
    ### lookup simulated values
    lmbda_H, alpha_H, sigma_H = lookup_alpha[H_twiddle][Z]
    lmbda_L, alpha_L, sigma_L = lookup_alpha[L_twiddle][Z]
    ax1.errorbar(alpha_H, alpha_H - alpha_L, xerr = sigma_H, 
                 yerr = np.sqrt(sigma_H**2 + sigma_L**2), 
                 elinewidth=2, capsize=2, ecolor = color(Z), ls='none')
        
    Z_fit, loss_fit = fitToTheory(alpha_H, alpha_L, b_H, b_L, R, E_dep, attenMat, attenMat, zRange)
    print("True Z: %d; Fit Z: %s; Loss: %s" % (Z, Z_fit, loss_fit))
    
    ### plot against theory
    alpha_H0 = calcAlpha(lmbdaRange, [Z_fit[0]], b_H, R, E_dep, attenMat, zRange)
    alpha_L0 = calcAlpha(lmbdaRange, [Z_fit[0]], b_L, R, E_dep, attenMat, zRange)        
    ax1.plot(alpha_H0, alpha_H0 - alpha_L0, linewidth = 1, linestyle = 'dashed', c=color(Z))

ax1.set_xlim(xrange)
ax1.set_ylim(yrange)
ax1.set_xticks(xticks)
ax1.set_yticks(yticks)
ax1.tick_params(labelsize=16)
ax1.grid()
ax1.set_xlabel(r"$\alpha_H(\lambda, Z)$", fontsize=19)
ax1.set_ylabel(r"$\alpha_H(\lambda, Z) - \alpha_L(\lambda, Z)$", fontsize=19)
ax1.text(0.1, 0.97*yrange[0], "{%s, %s} MeV" % (H, L), fontsize = 19)
fig.subplots_adjust(right=0.85)
cbar_ax = fig.add_axes([0.86, 0.125, 0.04, 0.755])
fig.colorbar(cmap, cax=cbar_ax)
cbar_ax.set_ylabel("Atomic Number (Z)", fontsize=19)
cbar_ax.tick_params(labelsize=16)
# Out:
# True Z: 1; Fit Z: [4]; Loss: [6.00661302e-05]
# True Z: 6; Fit Z: [9]; Loss: [0.00015202]
# True Z: 13; Fit Z: [16]; Loss: [7.76679875e-05]
# True Z: 20; Fit Z: [23]; Loss: [5.69293542e-05]
# True Z: 26; Fit Z: [29]; Loss: [6.64844604e-05]
# True Z: 32; Fit Z: [34]; Loss: [5.01965616e-05]
# True Z: 40; Fit Z: [42]; Loss: [3.18673816e-05]
# True Z: 47; Fit Z: [48]; Loss: [3.57036512e-05]
# True Z: 55; Fit Z: [57]; Loss: [4.20943463e-05]
# True Z: 64; Fit Z: [67 94]; Loss: [4.93919341e-05 9.13019098e-05]
# True Z: 74; Fit Z: [80]; Loss: [0.00011534]
# True Z: 82; Fit Z: [80]; Loss: [0.00034743]
# True Z: 92; Fit Z: [80]; Loss: [0.00030483]

# %% [markdown]
# ### Compound Materials

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = [16, 8], sharey = True)
fig.subplots_adjust(wspace=0)

for Z in Z_compound:        
    ### lookup simulated values
    lmbda_H, alpha_H, sigma_H = lookup_alpha[H_twiddle][Z]
    lmbda_L, alpha_L, sigma_L = lookup_alpha[L_twiddle][Z]
    ax1.errorbar(alpha_H, alpha_H - alpha_L, xerr = sigma_H, 
                 yerr = np.sqrt(sigma_H**2 + sigma_L**2), 
                 elinewidth=2, capsize=2, ecolor = compound_c[Z], ls='none')
    ax2.errorbar(alpha_H, alpha_H - alpha_L, xerr = sigma_H, 
                 yerr = np.sqrt(sigma_H**2 + sigma_L**2), 
                 elinewidth=2, capsize=2, ecolor = compound_c[Z], ls='none') 
        
    ### plot against theory
    alpha_H0 = np.array([calcCompoundAlpha(lmbda*compound_f[Z], compound_Z[Z], b_H, R, E_dep, attenMat, zRange) for lmbda in lmbdaRange])
    alpha_L0 = np.array([calcCompoundAlpha(lmbda*compound_f[Z], compound_Z[Z], b_L, R, E_dep, attenMat, zRange) for lmbda in lmbdaRange])
    ax1.plot(alpha_H0, alpha_H0 - alpha_L0, linewidth = 1, linestyle = 'dashed', color = compound_c[Z], label = compound_material[Z])
    
    alpha_H0 = np.array([calcCompoundAlpha(lmbda*compound_f[Z], compound_Z[Z], b_H, R, E_dep, attenMat_H, zRange) for lmbda in lmbdaRange])
    alpha_L0 = np.array([calcCompoundAlpha(lmbda*compound_f[Z], compound_Z[Z], b_L, R, E_dep, attenMat_L, zRange) for lmbda in lmbdaRange])
    ax2.plot(alpha_H0, alpha_H0 - alpha_L0, linewidth = 1, linestyle = 'dashed', color = compound_c[Z], label = compound_material[Z])

ax1.set_xlim([0,9])
ax2.set_xlim([0,9])
ax1.set_ylim(yrange)
ax1.set_xticks(np.arange(9))
ax2.set_xticks(np.arange(10))
ax1.set_yticks(yticks)
ax1.tick_params(labelsize=16)
ax2.tick_params(labelsize=16)
ax1.grid()
ax2.grid()
ax1.set_xlabel(r"$\alpha_H(\lambda, Z)$", fontsize=19)
ax2.set_xlabel(r"$\alpha_H(\lambda, Z)$", fontsize=19)
ax1.set_ylabel(r"$\alpha_H(\lambda, Z) - \alpha_L(\lambda, Z)$", fontsize=19)
ax1.legend(fontsize=19)

plt.savefig(outfile + "alpha_curve_%s%s_compound.png" % (H, L), bbox_inches = "tight")

# %% [markdown]
# ### Results summary

# %%
a0_H, b0_H, c0_H = fitSemiempirical(alpha_H_arr, lmbda_H_arr, Z_arr, b_H, R, E_dep, attenMat, attenMat_PE, attenMat_CS, attenMat_PP, zRange)
a0_L, b0_L, c0_L = fitSemiempirical(alpha_L_arr, lmbda_L_arr, Z_arr, b_L, R, E_dep, attenMat, attenMat_PE, attenMat_CS, attenMat_PP, zRange)
attenMat_H = attenMat + (a0_H-1)*attenMat_PE + (b0_H-1)*attenMat_CS + (c0_H-1)*attenMat_PP
attenMat_L = attenMat + (a0_L-1)*attenMat_PE + (b0_L-1)*attenMat_CS + (c0_L-1)*attenMat_PP

lmbda_calib = 150
cut = np.abs(lmbda_H_calib_twiddle - 1.068*lmbda_calib) < 10
a0_H, b0_H, c0_H = fitSemiempirical(alpha_H_calib_twiddle[cut], lmbda_H_calib_twiddle[cut], Z_arr_calib_twiddle[cut], b_H, R, E_dep, attenMat, attenMat_PE, attenMat_CS, attenMat_PP, zRange)
a0_L, b0_L, c0_L = fitSemiempirical(alpha_L_calib_twiddle[cut], lmbda_L_calib_twiddle[cut], Z_arr_calib_twiddle[cut], b_L, R, E_dep, attenMat, attenMat_PE, attenMat_CS, attenMat_PP, zRange)
attenMat_H_twiddle = attenMat + (a0_H-1)*attenMat_PE + (b0_H-1)*attenMat_CS + (c0_H-1)*attenMat_PP
attenMat_L_twiddle = attenMat + (a0_L-1)*attenMat_PE + (b0_L-1)*attenMat_CS + (c0_L-1)*attenMat_PP

fig, ((ax11, ax12), (ax21, ax22)) = plt.subplots(2, 2, figsize = [16, 16], sharex = True, sharey = True)
fig.subplots_adjust(wspace=0)
fig.subplots_adjust(hspace=0)

for Z in Z_vals:
    ### lookup simulated values
    lmbda_H, alpha_H, sigma_H = lookup_alpha[H][Z]
    lmbda_L, alpha_L, sigma_L = lookup_alpha[L][Z]
    ax11.errorbar(alpha_H, alpha_H - alpha_L, xerr = sigma_H, 
                  yerr = np.sqrt(sigma_H**2 + sigma_L**2), 
                  elinewidth=2, capsize=2, ecolor = color(Z), ls='none')
    ax12.errorbar(alpha_H, alpha_H - alpha_L, xerr = sigma_H, 
                  yerr = np.sqrt(sigma_H**2 + sigma_L**2), 
                  elinewidth=2, capsize=2, ecolor = color(Z), ls='none') 
    
    ### plot against theory
    alpha_H0 = calcAlpha(lmbdaRange, [Z], b_H, R, E_dep, attenMat, zRange)
    alpha_L0 = calcAlpha(lmbdaRange, [Z], b_L, R, E_dep, attenMat, zRange)        
    ax11.plot(alpha_H0, alpha_H0 - alpha_L0, linewidth = 1, linestyle = 'dashed', c=color(Z))
    
    alpha_H0 = calcAlpha(lmbdaRange, [Z], b_H, R, E_dep, attenMat_H, zRange)
    alpha_L0 = calcAlpha(lmbdaRange, [Z], b_L, R, E_dep, attenMat_L, zRange)        
    ax12.plot(alpha_H0, alpha_H0 - alpha_L0, linewidth = 1, linestyle = 'dashed', c=color(Z))
    
    
    ### TWIDDLE: lookup simulated values
    lmbda_H, alpha_H, sigma_H = lookup_alpha[H_twiddle][Z]
    lmbda_L, alpha_L, sigma_L = lookup_alpha[L_twiddle][Z]
    ax21.errorbar(alpha_H, alpha_H - alpha_L, xerr = sigma_H, 
                 yerr = np.sqrt(sigma_H**2 + sigma_L**2), 
                 elinewidth=2, capsize=2, ecolor = color(Z), ls='none')
    ax22.errorbar(alpha_H, alpha_H - alpha_L, xerr = sigma_H, 
                 yerr = np.sqrt(sigma_H**2 + sigma_L**2), 
                 elinewidth=2, capsize=2, ecolor = color(Z), ls='none') 
    
    ### TWIDDLE: plot against theory
    alpha_H0 = calcAlpha(lmbdaRange, [Z], b_H, R, E_dep, attenMat, zRange)
    alpha_L0 = calcAlpha(lmbdaRange, [Z], b_L, R, E_dep, attenMat, zRange)        
    ax21.plot(alpha_H0, alpha_H0 - alpha_L0, linewidth = 1, linestyle = 'dashed', c=color(Z))
    
    alpha_H0 = calcAlpha(lmbdaRange, [Z], b_H, R, E_dep, attenMat_H_twiddle, zRange)
    alpha_L0 = calcAlpha(lmbdaRange, [Z], b_L, R, E_dep, attenMat_L_twiddle, zRange)        
    ax22.plot(alpha_H0, alpha_H0 - alpha_L0, linewidth = 1, linestyle = 'dashed', c=color(Z))

ax11.set_xlim(xrange)
ax12.set_xlim(xrange)
ax21.set_ylim(yrange)
ax22.set_ylim(yrange)
ax21.set_xticks(xticks[:-1])
ax11.set_yticks(yticks[1:])
ax11.tick_params(labelsize=16)
ax12.tick_params(labelsize=16)
ax21.tick_params(labelsize=16)
ax22.tick_params(labelsize=16)
ax11.grid()
ax12.grid()
ax21.grid()
ax22.grid()
ax21.set_xlabel(r"$\alpha_H(\lambda, Z)$", fontsize=19)
ax22.set_xlabel(r"$\alpha_H(\lambda, Z)$", fontsize=19)
ax11.set_ylabel(r"$\alpha_H(\lambda, Z) - \alpha_L(\lambda, Z)$", fontsize=19)
ax21.set_ylabel(r"$\alpha_H(\lambda, Z) - \alpha_L(\lambda, Z)$", fontsize=19)

fig.subplots_adjust(right=0.85)
cbar_ax = fig.add_axes([0.855, 0.125, 0.015, 0.755])
fig.colorbar(cmap, cax=cbar_ax)
cbar_ax.set_ylabel("Atomic Number (Z)", fontsize=19)
cbar_ax.tick_params(labelsize=16)

plt.savefig(outfile + "alpha_curve_%s%s_2x2.png" % (H, L), bbox_inches = "tight")
# Out:
# Minimum found at a = 1.1658, b=0.9861, c=0.9920 with a loss of 2.502e-04
# Minimum found at a = 1.1045, b=1.0054, c=0.9612 with a loss of 4.931e-04
# Minimum found at a = 1.1684, b=1.0074, c=0.9607 with a loss of 7.614e-13
# Minimum found at a = 0.8778, b=0.9692, c=1.0577 with a loss of 8.593e-12

# %% [markdown]
# ### Debug

# %%
def readDat(filename):
    """Calculates the total energy deposited (and uncertainty) for filename"""
    line_number = 2 #skip header
    with open(filename) as f:
        header = np.array(f.readline().split())
        E_beam_idx = np.argmax(header == "E_beam(MeV)")
        E_incident_idx = np.argmax(header == "E_incident(MeV)")
        creator_process_idx = np.argmax(header == "CreatorProcessName")
        event_ID_idx = np.argmax(header == "EventID")
        particle_name_idx = np.argmax(header == "ParticleName")
        for line in f:
            entries = line.split()
            E_beam = entries[E_beam_idx]
            E_incident = entries[E_incident_idx]
            creator_process = entries[creator_process_idx]
            event_ID = entries[event_ID_idx]
            particle_name = entries[particle_name_idx]
            
            #if particle_name != "gamma":
            #    continue
                
            if creator_process != "EventGenerator" and event_ID != event_ID_prev:
                print("creator_process = %s; line %d" % (creator_process, line_number))
                
            elif E_beam != E_incident:
                print("Compton scatter: line %d" % line_number)
 
            event_ID_prev = event_ID
            line_number += 1
    
readDat("/Users/peter/Work/alphaCurveSim/src/debug/E=10MeV-lmbda=100-Z=26-N=1000000.dat")
# Out:
# Compton scatter: line 142
# Compton scatter: line 143
# Compton scatter: line 288
# Compton scatter: line 289
# Compton scatter: line 290
# Compton scatter: line 835
# Compton scatter: line 836
# Compton scatter: line 837
# Compton scatter: line 838
# Compton scatter: line 923
# Compton scatter: line 924
# Compton scatter: line 925
# Compton scatter: line 926
# Compton scatter: line 927
# Compton scatter: line 928
# Compton scatter: line 929
# Compton scatter: line 930
# creator_process = compt; line 1844
# Compton scatter: line 1866
# Compton scatter: line 1867
# Compton scatter: line 1868
# Compton scatter: line 1869
# Compton scatter: line 1870
# Compton scatter: line 1871
# Compton scatter: line 1916
# Compton scatter: line 1917
# Compton scatter: line 2007
# Compton scatter: line 2008
# Compton scatter: line 2009
# Compton scatter: line 2330
# Compton scatter: line 2331
# Compton scatter: line 2332
# creator_process = eBrem; line 3192
# creator_process = eBrem; line 3333
# Compton scatter: line 3334
# Compton scatter: line 3335
# Compton scatter: line 3610
# Compton scatter: line 3611
# Compton scatter: line 3612
# Compton scatter: line 3613
# Compton scatter: line 3614
# Compton scatter: line 3615
# Compton scatter: line 3616
# Compton scatter: line 3617
# Compton scatter: line 3618
# Compton scatter: line 3619
# Compton scatter: line 3620
# Compton scatter: line 3621
# Compton scatter: line 3622
# Compton scatter: line 3623
# Compton scatter: line 3810
# Compton scatter: line 3811
# Compton scatter: line 3812
# Compton scatter: line 3813
# Compton scatter: line 3814
# Compton scatter: line 3815
# Compton scatter: line 3901
# Compton scatter: line 3902
# Compton scatter: line 3903
# Compton scatter: line 3904
# Compton scatter: line 3905
# Compton scatter: line 3906
# Compton scatter: line 4212
# Compton scatter: line 4213
# Compton scatter: line 4326
# Compton scatter: line 4327
# Compton scatter: line 4385
# Compton scatter: line 4501
# Compton scatter: line 4502
# Compton scatter: line 4503
# Compton scatter: line 4778
# Compton scatter: line 4779
# Compton scatter: line 5183
# Compton scatter: line 5184
# Compton scatter: line 5185
# Compton scatter: line 5186
# Compton scatter: line 5312
# Compton scatter: line 5313
# Compton scatter: line 5314
# Compton scatter: line 5315
# Compton scatter: line 5316
# Compton scatter: line 5317
# Compton scatter: line 5454
# creator_process = compt; line 6365
# Compton scatter: line 6438
# creator_process = annihil; line 6787
# Compton scatter: line 6788
# Compton scatter: line 7930
# Compton scatter: line 7931
# Compton scatter: line 7994
# Compton scatter: line 7995
# Compton scatter: line 7996
# Compton scatter: line 7997
# Compton scatter: line 7998
# Compton scatter: line 7999
# Compton scatter: line 8000
# creator_process = annihil; line 8027
# Compton scatter: line 8028
# Compton scatter: line 8178
# Compton scatter: line 8179
# Compton scatter: line 8180
# Compton scatter: line 8214
# Compton scatter: line 8215
# Compton scatter: line 8216
# Compton scatter: line 8217
# creator_process = compt; line 8354
# Compton scatter: line 8355
# Compton scatter: line 8356
# Compton scatter: line 8480
# Compton scatter: line 8766
# Compton scatter: line 8958
# Compton scatter: line 8959
# Compton scatter: line 8960
# Compton scatter: line 8961
# Compton scatter: line 8962
# Compton scatter: line 8963
# Compton scatter: line 8964
# Compton scatter: line 8965
# Compton scatter: line 8966
# Compton scatter: line 8967
# Compton scatter: line 8968
# Compton scatter: line 8969
# Compton scatter: line 8970
# Compton scatter: line 8971
# Compton scatter: line 8972
# Compton scatter: line 8973
# Compton scatter: line 9067
# Compton scatter: line 9068
# Compton scatter: line 9069
# Compton scatter: line 9872
# Compton scatter: line 9873
# Compton scatter: line 9895
# Compton scatter: line 10268
# Compton scatter: line 10269
# Compton scatter: line 10270
# Compton scatter: line 10271
# Compton scatter: line 10272
# Compton scatter: line 10497
# Compton scatter: line 10693
# Compton scatter: line 10694
# Compton scatter: line 10695
# Compton scatter: line 10696
# Compton scatter: line 10697
# Compton scatter: line 10698
# Compton scatter: line 10699
# Compton scatter: line 10700
# Compton scatter: line 10981
# Compton scatter: line 11167
# Compton scatter: line 11181
# creator_process = compt; line 11202
# Compton scatter: line 11407
# Compton scatter: line 11408
# Compton scatter: line 11409
# Compton scatter: line 11742
# Compton scatter: line 11767
# Compton scatter: line 11768
# Compton scatter: line 11769
# Compton scatter: line 11770
# Compton scatter: line 13062
# Compton scatter: line 13063
# Compton scatter: line 13064
# Compton scatter: line 13065
# Compton scatter: line 13066
# Compton scatter: line 13432
# Compton scatter: line 14120
# Compton scatter: line 14121
# Compton scatter: line 14335
# Compton scatter: line 14336
# Compton scatter: line 14337
# Compton scatter: line 14338
# Compton scatter: line 14339
# Compton scatter: line 15122
# Compton scatter: line 15123
# Compton scatter: line 15124
# Compton scatter: line 15125
# Compton scatter: line 15126
# Compton scatter: line 15127
# Compton scatter: line 15186
# Compton scatter: line 15187
# Compton scatter: line 15188
# Compton scatter: line 15189
# Compton scatter: line 15190
# Compton scatter: line 15191
# Compton scatter: line 15196
# Compton scatter: line 15647
# Compton scatter: line 15648
# Compton scatter: line 15853
# Compton scatter: line 15854
# Compton scatter: line 15855
# Compton scatter: line 15865
# Compton scatter: line 16105
# Compton scatter: line 16106
# Compton scatter: line 16148
# Compton scatter: line 16372
# Compton scatter: line 16801
# Compton scatter: line 16802
# Compton scatter: line 16803
# Compton scatter: line 16804
# Compton scatter: line 16805
# Compton scatter: line 16977
# Compton scatter: line 16978
# Compton scatter: line 16979
# Compton scatter: line 16980
# Compton scatter: line 16981
# Compton scatter: line 16982
# Compton scatter: line 16983
# Compton scatter: line 18084
# Compton scatter: line 18085
# Compton scatter: line 18086
# Compton scatter: line 18087
# Compton scatter: line 18088
# Compton scatter: line 18089
# Compton scatter: line 19378
# Compton scatter: line 19407
# Compton scatter: line 20357
# Compton scatter: line 20358
# Compton scatter: line 20359
# Compton scatter: line 20360
# Compton scatter: line 20361
# Compton scatter: line 20362
# Compton scatter: line 20363
# Compton scatter: line 20364
# Compton scatter: line 20365
# Compton scatter: line 20366
# Compton scatter: line 20367
# Compton scatter: line 20368
# Compton scatter: line 20369
# Compton scatter: line 20620
# Compton scatter: line 20621
# Compton scatter: line 20622
# Compton scatter: line 21277
# Compton scatter: line 21278
# Compton scatter: line 21279
# Compton scatter: line 21367
# Compton scatter: line 21368
# Compton scatter: line 21369
# Compton scatter: line 21370
# Compton scatter: line 21371
# Compton scatter: line 21495
# Compton scatter: line 21496
# Compton scatter: line 21971
# Compton scatter: line 22430
# Compton scatter: line 22431
# Compton scatter: line 22570
# Compton scatter: line 22571
# Compton scatter: line 22659
# Compton scatter: line 22824
# Compton scatter: line 22825
# Compton scatter: line 22826
# Compton scatter: line 22827
# Compton scatter: line 22828
# Compton scatter: line 24384
# Compton scatter: line 24385
# Compton scatter: line 24386
# Compton scatter: line 24579
# Compton scatter: line 24943
# Compton scatter: line 24944
# Compton scatter: line 24945
# Compton scatter: line 24946
# Compton scatter: line 24947
# Compton scatter: line 24948
# Compton scatter: line 25455
# Compton scatter: line 25456
# Compton scatter: line 25457
# Compton scatter: line 25458
# Compton scatter: line 25459
# Compton scatter: line 25460
# Compton scatter: line 25461
# Compton scatter: line 25462
# Compton scatter: line 25463
# Compton scatter: line 25464
# Compton scatter: line 26887
# Compton scatter: line 27810
# Compton scatter: line 27868
# Compton scatter: line 27899
# Compton scatter: line 27900
# Compton scatter: line 27901
# Compton scatter: line 27902
# Compton scatter: line 27903
# Compton scatter: line 27965
# Compton scatter: line 27966
# Compton scatter: line 27967
# Compton scatter: line 27968
# Compton scatter: line 28182
# Compton scatter: line 28210
# Compton scatter: line 28600
# Compton scatter: line 28601
# Compton scatter: line 28602
# Compton scatter: line 28603
# Compton scatter: line 28604
# Compton scatter: line 28605
# Compton scatter: line 28614
# Compton scatter: line 28983
# Compton scatter: line 28984
# Compton scatter: line 28985
# Compton scatter: line 29142
# Compton scatter: line 29143
# Compton scatter: line 29144
# Compton scatter: line 29145
# Compton scatter: line 29146
# Compton scatter: line 29147
# Compton scatter: line 29148
# Compton scatter: line 29149
# Compton scatter: line 29869
# Compton scatter: line 29870
# Compton scatter: line 29871
# Compton scatter: line 29872
# Compton scatter: line 29873
# Compton scatter: line 29874
# Compton scatter: line 29875
# Compton scatter: line 29876
# Compton scatter: line 29877
# Compton scatter: line 29878
# Compton scatter: line 29879
# creator_process = annihil; line 30468
# Compton scatter: line 30469
# Compton scatter: line 30470
# Compton scatter: line 31179
# Compton scatter: line 31180
# Compton scatter: line 31181
# Compton scatter: line 31182
# Compton scatter: line 31183
# Compton scatter: line 31184
# Compton scatter: line 31919
# Compton scatter: line 31920
# Compton scatter: line 32494
# Compton scatter: line 32495
# Compton scatter: line 32496
# creator_process = eBrem; line 32663
# Compton scatter: line 32664
# Compton scatter: line 32773
# Compton scatter: line 32774
# Compton scatter: line 32775
# Compton scatter: line 32894
# Compton scatter: line 32895
# Compton scatter: line 32896
# Compton scatter: line 32988
# Compton scatter: line 32989
# Compton scatter: line 32990
# Compton scatter: line 33013
# Compton scatter: line 33538
# Compton scatter: line 33539
# Compton scatter: line 33540
# Compton scatter: line 33541
# Compton scatter: line 33598
# Compton scatter: line 33599
# Compton scatter: line 33600
# Compton scatter: line 33601
# Compton scatter: line 33647
# Compton scatter: line 33648
# Compton scatter: line 33649
# Compton scatter: line 33650
# Compton scatter: line 33651
# Compton scatter: line 33652
# Compton scatter: line 33653
# Compton scatter: line 33665
# Compton scatter: line 33666
# Compton scatter: line 33667
# Compton scatter: line 33668
# Compton scatter: line 33669
# Compton scatter: line 33670
# Compton scatter: line 34053
# Compton scatter: line 34054
# Compton scatter: line 34055
# Compton scatter: line 34056
# Compton scatter: line 34057
# Compton scatter: line 34058
# Compton scatter: line 34383
# Compton scatter: line 34384
# Compton scatter: line 34385
# Compton scatter: line 34386
# Compton scatter: line 35557
# Compton scatter: line 35558
# Compton scatter: line 35559
# Compton scatter: line 35560
# Compton scatter: line 35561
# Compton scatter: line 35903
# Compton scatter: line 35904
# Compton scatter: line 35905
# Compton scatter: line 35906
# Compton scatter: line 35907
# Compton scatter: line 35908
# Compton scatter: line 36661
# Compton scatter: line 36751
# Compton scatter: line 36812
# Compton scatter: line 36813
# Compton scatter: line 36814
# Compton scatter: line 36815
# Compton scatter: line 37151
# Compton scatter: line 37152
# Compton scatter: line 37153
# Compton scatter: line 38103
# Compton scatter: line 38104
# Compton scatter: line 38105
# Compton scatter: line 38106
# creator_process = compt; line 38375
# Compton scatter: line 38484
# Compton scatter: line 38485
# Compton scatter: line 38812
# Compton scatter: line 38870
# Compton scatter: line 38871
# Compton scatter: line 38872
# Compton scatter: line 39095
# creator_process = eBrem; line 39229
# Compton scatter: line 39230
# Compton scatter: line 40393
# Compton scatter: line 40438
# Compton scatter: line 40439
# Compton scatter: line 40691
# Compton scatter: line 40692
# Compton scatter: line 41296
# Compton scatter: line 41297
# Compton scatter: line 41298
# Compton scatter: line 41501
# Compton scatter: line 41502
# Compton scatter: line 42108
# Compton scatter: line 42109
# Compton scatter: line 42110
# Compton scatter: line 42111
# Compton scatter: line 42112
# Compton scatter: line 42113
# Compton scatter: line 42114
# Compton scatter: line 42587
# Compton scatter: line 42588
# Compton scatter: line 42599
# Compton scatter: line 42600
# Compton scatter: line 42601
# Compton scatter: line 42602
# Compton scatter: line 42603
# Compton scatter: line 42604
# Compton scatter: line 42605
# Compton scatter: line 42606
# Compton scatter: line 42607
# Compton scatter: line 42608
# Compton scatter: line 42609
# Compton scatter: line 42610
# Compton scatter: line 43634
# Compton scatter: line 43635
# Compton scatter: line 43636
# Compton scatter: line 43637
# Compton scatter: line 43638
# Compton scatter: line 43639
# Compton scatter: line 43640
# Compton scatter: line 43899
# Compton scatter: line 43900
# Compton scatter: line 43901
# Compton scatter: line 43902
# Compton scatter: line 44223
# Compton scatter: line 44224
# Compton scatter: line 44225
# Compton scatter: line 44226
# Compton scatter: line 44227
# Compton scatter: line 44228
# creator_process = compt; line 44448
# Compton scatter: line 45215
# Compton scatter: line 45681
